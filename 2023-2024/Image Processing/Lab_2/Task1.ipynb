# %%
# Testing Data
from PIL import Image
import sys
from numpy import *
img = Image.open("test_image.bmp")
img.show()
newImage = asarray(img)
print(newImage)
# Out:
# [[[178 130 144]
#   [173 125 139]
#   [170 122 138]
#   ...
#   [125  93 117]
#   [124  88 114]
#   [122  86 112]]
#
#  [[178 130 144]
#   [175 127 141]
#   [173 125 141]
#   ...
#   [127  93 118]
#   [125  89 115]
#   [123  87 113]]
#
#  [[178 130 144]
#   [177 129 143]
#   [176 128 144]
#   ...
#   [126  92 117]
#   [125  89 115]
#   [127  88 115]]
#
#  ...
#
#  [[  0   1   0]
#   [ 17  19  16]
#   [  3   2   0]
#   ...
#   [ 14  24   0]
#   [ 67  78  10]
#   [ 93 104  36]]
#
#  [[  4   6   1]
#   [  7   9   4]
#   [  9   8   6]
#   ...
#   [ 55  64   0]
#   [ 26  37   0]
#   [ 92 103  35]]
#
#  [[  4   6   1]
#   [  7   9   4]
#   [  9   8   6]
#   ...
#   [ 91 100  33]
#   [ 44  53   0]
#   [115 126  58]]]

# %%
# Task 1: Display the image using matplotlib
import numpy as np
import pandas as pd
df= pd.read_csv('data.csv')
check = df.to_numpy()
import matplotlib.pyplot as plt
plt.matshow(check, cmap='gray')
plt.show()

# Q: Why we are getting gray-scale image
# Answer: The data uses a range of 0-255 to represent the intensity of the pixel, where 0 is black and 255 is white. Since it is using 1 array instead of 3 arrays for RGB
# Out:
# /var/folders/md/mq14r15x32dbk_dp73cffn_40000gn/T/ipykernel_32414/2435607959.py:3: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
# Task 2: Display a part of the image using slicing
import numpy as np
import pandas as pd
df= pd.read_csv('data.csv')
check = df.to_numpy()
import matplotlib.pyplot as plt
plt.matshow(check[0:2,0:2], cmap='gray')
